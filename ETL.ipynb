# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import logging

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, KFold
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from lightgbm import LGBMRegressor, LGBMClassifier
from sklearn.metrics import (mean_absolute_error, mean_squared_error, r2_score, roc_auc_score, accuracy_score, 
                             f1_score, recall_score, precision_score, confusion_matrix, classification_report, 
                             precision_recall_fscore_support, roc_curve)

# %%
df_x = pd.read_csv('Data/X.csv')
df_y = pd.read_csv('Data/target.csv')

df = pd.concat([df_x, df_y], axis=1)

df.head()
# Out:
#    funded_amnt  interest_rate  monthly_payment grade       emp_title  \
# 0         2500          13.56            84.92    C1            Chef
# 1        30000          18.94           777.23    D2     Postmaster
# 2         5000          17.97           180.69    D1  Administrative
# 3         4000          18.94           146.51    D2   IT Supervisor
# 4        30000          16.14           731.78    C4        Mechanic
#
#   emp_length home_ownership_status  annual_income verification_status  \
# 0  10+ years                  RENT        55000.0        Not Verified
# 1  10+ years              MORTGAGE        90000.0     Source Verified
# 2    6 years              MORTGAGE        59280.0     Source Verified
# 3  10+ years              MORTGAGE        92000.0     Source Verified
# 4  10+ years              MORTGAGE        57250.0        Not Verified
#
#          loan_purpose  ... mths_since_recent_bankcard_delinq  \
# 0  debt_consolidation  ...                               NaN
# 1  debt_consolidation  ...                               NaN
# 2  debt_consolidation  ...                               NaN
# 3  debt_consolidation  ...                               NaN
# 4  debt_consolidation  ...                               NaN
#
#    mths_since_recent_revol_delinq  disbursement_method  loan_term_months  \
# 0                             NaN                 Cash                36
# 1                             NaN                 Cash                60
# 2                             NaN                 Cash                36
# 3                             NaN                 Cash                36
# 4                             NaN                 Cash                60
#
#    issue_date_month  issue_date_year  region_code  earliest_cr_line_month  \
# 0               Dec             2018            1                     Apr
# 1               Dec             2018            7                     Jun
# 2               Dec             2018            4                     Apr
# 3               Dec             2018            9                     Feb
# 4               Dec             2018            2                     Dec
#
#    earliest_cr_line_year  y
# 0                   2001  0
# 1                   1987  0
# 2                   2011  0
# 3                   2006  0
# 4                   2000  0
#
# [5 rows x 46 columns]

# %%
df.describe().T
# Out:
#                                         count          mean            std  \
# funded_amnt                         2139643.0  14782.296100    9033.085915
# interest_rate                       2139643.0     13.059646       4.795935
# monthly_payment                     2139643.0    439.304234     263.363421
# annual_income                       2139643.0  78987.774254  115041.933734
# dept_paym_income_ratio              2139643.0     18.093687       8.425314
# num_30+_delinq_in_2yrs              2139643.0      0.309936       0.872271
# num_inq_in_6mths                    2139643.0      0.587227       0.894615
# mths_since_last_delinq              1048646.0     34.503356      21.896744
# num_open_credit_lines               2139643.0     11.640173       5.643363
# num_derogatory_pub_rec              2139643.0      0.199921       0.577406
# total_credit_revolving_bal          2139643.0  16654.422991   22931.829254
# used_credit_share                   2139643.0     50.486664      24.647308
# tot_num_credit_lines                2139643.0     24.245791      12.008366
# remaining_princ_for_tot_amnt_fund   2139643.0   3989.053616    7078.668007
# paym_rec_for_tot_amnt_fund          2139643.0  12008.634532    9926.122640
# princ_rec                           2139643.0   9468.659164    8310.755720
# interest_rec                        2139643.0   2397.628601    2687.779194
# late_fees_rec                       2139643.0      1.452790      11.424155
# num_open_trades_in_6mths            1273987.0      0.943083       1.147632
# num_installment_acc_op_in_12mths    1273987.0      0.678187       0.927349
# num_installment_acc_op_in_24mths    1273987.0      1.568759       1.581522
# mths_since_last_installment_acc_op  1234387.0     21.132848      25.967078
# num_rev_trades_op_in_12mths         1273987.0      1.312712       1.521737
# num_rev_trades_op_in_24mths         1273987.0      2.794102       2.622061
# max_bal_owed                        1273987.0   5793.606271    5683.010238
# bal_to_cred_lim                     1273868.0     57.076408      20.856251
# num_inq                             1273987.0      1.008200       1.484976
# num_inq_in_12mths                   2139643.0      1.496261       2.049036
# mths_since_recent_bankcard_delinq    496141.0     39.316249      22.624102
# mths_since_recent_revol_delinq       705752.0     35.754465      22.312709
# loan_term_months                    2139643.0     42.729029      10.780395
# issue_date_year                     2139643.0   2015.765757       1.791998
# region_code                         2139643.0      4.643012       3.102937
# earliest_cr_line_year               2139643.0   1999.399747       7.829945
# y                                   2139643.0      0.130730       0.337105
#
#                                              min           25%       50%  \
# funded_amnt                         5.000000e+02   8000.000000  12250.00
# interest_rate                       5.310000e+00      9.490000     12.62
# monthly_payment                     4.930000e+00    249.130000    373.22
# annual_income                       1.896000e+03  47400.000000  65299.00
# dept_paym_income_ratio             -1.000000e+00     11.780000     17.60
# num_30+_delinq_in_2yrs              0.000000e+00      0.000000      0.00
# num_inq_in_6mths                    0.000000e+00      0.000000      0.00
# mths_since_last_delinq              0.000000e+00     16.000000     31.00
# num_open_credit_lines               0.000000e+00      8.000000     11.00
# num_derogatory_pub_rec              0.000000e+00      0.000000      0.00
# total_credit_revolving_bal          0.000000e+00   5985.000000  11328.00
# used_credit_share                   0.000000e+00     31.800000     50.40
# tot_num_credit_lines                1.000000e+00     15.000000     22.00
# remaining_princ_for_tot_amnt_fund   0.000000e+00      0.000000      0.00
# paym_rec_for_tot_amnt_fund          0.000000e+00   4417.299784   9303.08
# princ_rec                           0.000000e+00   3000.000000   7000.00
# interest_rec                        0.000000e+00    694.515000   1484.82
# late_fees_rec                      -9.500000e-09      0.000000      0.00
# num_open_trades_in_6mths            0.000000e+00      0.000000      1.00
# num_installment_acc_op_in_12mths    0.000000e+00      0.000000      0.00
# num_installment_acc_op_in_24mths    0.000000e+00      0.000000      1.00
# mths_since_last_installment_acc_op  0.000000e+00      7.000000     13.00
# num_rev_trades_op_in_12mths         0.000000e+00      0.000000      1.00
# num_rev_trades_op_in_24mths         0.000000e+00      1.000000      2.00
# max_bal_owed                        0.000000e+00   2301.000000   4403.00
# bal_to_cred_lim                     0.000000e+00     43.000000     58.00
# num_inq                             0.000000e+00      0.000000      0.00
# num_inq_in_12mths                   0.000000e+00      0.000000      1.00
# mths_since_recent_bankcard_delinq   0.000000e+00     21.000000     37.00
# mths_since_recent_revol_delinq      0.000000e+00     17.000000     33.00
# loan_term_months                    3.600000e+01     36.000000     36.00
# issue_date_year                     2.007000e+03   2015.000000   2016.00
# region_code                         0.000000e+00      2.000000      4.00
# earliest_cr_line_year               1.933000e+03   1995.000000   2001.00
# y                                   0.000000e+00      0.000000      0.00
#
#                                           75%           max
# funded_amnt                         20000.000  4.000000e+04
# interest_rate                          15.880  3.099000e+01
# monthly_payment                       581.600  1.719830e+03
# annual_income                       95000.000  1.100000e+08
# dept_paym_income_ratio                 24.040  4.996000e+01
# num_30+_delinq_in_2yrs                  0.000  5.800000e+01
# num_inq_in_6mths                        1.000  3.300000e+01
# mths_since_last_delinq                 50.000  2.260000e+02
# num_open_credit_lines                  14.000  1.010000e+02
# num_derogatory_pub_rec                  0.000  8.600000e+01
# total_credit_revolving_bal          20207.000  2.904836e+06
# used_credit_share                      69.400  8.923000e+02
# tot_num_credit_lines                   31.000  1.760000e+02
# remaining_princ_for_tot_amnt_fund    5704.030  4.000000e+04
# paym_rec_for_tot_amnt_fund          16940.985  6.329688e+04
# princ_rec                           13944.260  4.000000e+04
# interest_rec                         3057.790  2.819250e+04
# late_fees_rec                           0.000  1.427250e+03
# num_open_trades_in_6mths                1.000  1.800000e+01
# num_installment_acc_op_in_12mths        1.000  2.500000e+01
# num_installment_acc_op_in_24mths        2.000  5.100000e+01
# mths_since_last_installment_acc_op     24.000  5.110000e+02
# num_rev_trades_op_in_12mths             2.000  2.800000e+01
# num_rev_trades_op_in_24mths             4.000  6.000000e+01
# max_bal_owed                         7557.000  1.170668e+06
# bal_to_cred_lim                        72.000  2.390000e+02
# num_inq                                 1.000  4.800000e+01
# num_inq_in_12mths                       2.000  6.700000e+01
# mths_since_recent_bankcard_delinq      57.000  2.020000e+02
# mths_since_recent_revol_delinq         51.000  2.020000e+02
# loan_term_months                       60.000  6.000000e+01
# issue_date_year                      2017.000  2.018000e+03
# region_code                             8.000  9.000000e+00
# earliest_cr_line_year                2005.000  2.015000e+03
# y                                       0.000  1.000000e+00

# %% [markdown]
# We are removing variables that may cause data leakage, as they provide indirect information about the target class (delinquents).

# %%
cols_leakage = [
    'princ_rec',
    'interest_rec', 
    'late_fees_rec',
    'paym_rec_for_tot_amnt_fund',
    'remaining_princ_for_tot_amnt_fund'
]

df = df.drop(columns=cols_leakage)

# %%
df['y'].value_counts()
# Out:
# y
# 0    1859927
# 1     279716
# Name: count, dtype: int64

# %% [markdown]
# There is a clear class imbalance:

# %%
desbalanceo = (df[df['y'] == 1].count() / df[df['y'] == 0].count()) * 100
print(f"Hay un desbalanceo de clases de {desbalanceo.values[0]:.2f}% morosos sobre el total.")
# Out:
# Hay un desbalanceo de clases de 15.04% morosos sobre el total.

# %%
df.rename(columns={
    'y': 'moroso'
}, inplace=True)

# %%
df.isnull().sum().sort_values(ascending=False).head(15)
# Out:
# mths_since_recent_bankcard_delinq     1643502
# mths_since_recent_revol_delinq        1433891
# mths_since_last_delinq                1090997
# mths_since_last_installment_acc_op     905256
# bal_to_cred_lim                        865775
# num_open_trades_in_6mths               865656
# num_installment_acc_op_in_24mths       865656
# num_installment_acc_op_in_12mths       865656
# num_rev_trades_op_in_12mths            865656
# num_rev_trades_op_in_24mths            865656
# num_inq                                865656
# max_bal_owed                           865656
# emp_title                              148527
# emp_length                             130346
# interest_rate                               0
# dtype: int64

# %%
df.isnull().mean().sort_values(ascending=False).head(15)
# Out:
# mths_since_recent_bankcard_delinq     0.768120
# mths_since_recent_revol_delinq        0.670154
# mths_since_last_delinq                0.509897
# mths_since_last_installment_acc_op    0.423087
# bal_to_cred_lim                       0.404635
# num_open_trades_in_6mths              0.404580
# num_installment_acc_op_in_24mths      0.404580
# num_installment_acc_op_in_12mths      0.404580
# num_rev_trades_op_in_12mths           0.404580
# num_rev_trades_op_in_24mths           0.404580
# num_inq                               0.404580
# max_bal_owed                          0.404580
# emp_title                             0.069417
# emp_length                            0.060920
# interest_rate                         0.000000
# dtype: float64

# %% [markdown]
# Since the variables with NaN > 0.15%—such as months since last delinquency or number of accounts installed in 12/24 months—have overlapping NaNs, I will fill the NaNs up to 'num_inq' with 0.

# %%
columnas = ['mths_since_recent_bankcard_delinq', 
            'mths_since_recent_revol_delinq',
            'mths_since_last_delinq',
            'mths_since_last_installment_acc_op',
            'bal_to_cred_lim',
            'num_installment_acc_op_in_12mths',
            'num_installment_acc_op_in_24mths',
            'num_open_trades_in_6mths',
            'num_rev_trades_op_in_12mths',
            'max_bal_owed',
            'num_rev_trades_op_in_24mths',
            'num_inq']

df[columnas] = df[columnas].fillna(0)

# %%
df.isnull().mean().sort_values(ascending=False).head()
# Out:
# emp_title          0.069417
# emp_length         0.060920
# funded_amnt        0.000000
# monthly_payment    0.000000
# interest_rate      0.000000
# dtype: float64

# %%
df['emp_length'].value_counts()
# Out:
# emp_length
# 10+ years    714363
# 2 years      194813
# 3 years      172765
# < 1 year     167859
# 1 year       142335
# 5 years      133519
# 4 years      130607
# 6 years       98444
# 7 years       89299
# 8 years       88624
# 9 years       76669
# Name: count, dtype: int64

# %% [markdown]
# We create the necessary financial variables, feature engineering:

# %%
# 1
df['LGD'] = 100 * df['max_bal_owed'] / df['funded_amnt']

# 2
df['EAD'] = df['funded_amnt']

# 3
df.rename(columns={'moroso': 'PD'}, inplace=True)

# %%
df = df[df['LGD'] < 300]

# %%
# We are defining the targets, because in boxplots, PD=1 would be detected as an outlier. Also we have capped LGD < 300.
target_cols = ['PD', 'LGD', 'EAD']

num_cols = [col for col in df.select_dtypes(include=[np.number]).columns 
            if col not in target_cols]

num_cols
# Out:
# ['funded_amnt',
#  'interest_rate',
#  'monthly_payment',
#  'annual_income',
#  'dept_paym_income_ratio',
#  'num_30+_delinq_in_2yrs',
#  'num_inq_in_6mths',
#  'mths_since_last_delinq',
#  'num_open_credit_lines',
#  'num_derogatory_pub_rec',
#  'total_credit_revolving_bal',
#  'used_credit_share',
#  'tot_num_credit_lines',
#  'num_open_trades_in_6mths',
#  'num_installment_acc_op_in_12mths',
#  'num_installment_acc_op_in_24mths',
#  'mths_since_last_installment_acc_op',
#  'num_rev_trades_op_in_12mths',
#  'num_rev_trades_op_in_24mths',
#  'max_bal_owed',
#  'bal_to_cred_lim',
#  'num_inq',
#  'num_inq_in_12mths',
#  'mths_since_recent_bankcard_delinq',
#  'mths_since_recent_revol_delinq',
#  'loan_term_months',
#  'issue_date_year',
#  'region_code',
#  'earliest_cr_line_year']

# %%
plt.figure(figsize=(45, 20))
sns.heatmap(df[num_cols].corr(), 
            cmap="viridis", 
            fmt=".2f",
            annot=True,
            annot_kws={"size": 8},
            square=True,
            cbar=True)
plt.title('Correlation Matrix of Ordinal Data', fontsize=20)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
cat_cols = df.select_dtypes(include=['object']).columns
cat_cols
# Out:
# Index(['grade', 'emp_title', 'emp_length', 'home_ownership_status',
#        'verification_status', 'loan_purpose', 'addr_state',
#        'initial_list_status', 'disbursement_method', 'issue_date_month',
#        'earliest_cr_line_month'],
#       dtype='object')

# %%
for col in cat_cols:
    n_unique = df[col].nunique()
    print(f"{col}: {n_unique} categorías únicas")
# Out:
# grade: 35 categorías únicas
# emp_title: 494981 categorías únicas
# emp_length: 11 categorías únicas
# home_ownership_status: 4 categorías únicas
# verification_status: 3 categorías únicas
# loan_purpose: 14 categorías únicas
# addr_state: 51 categorías únicas
# initial_list_status: 2 categorías únicas
# disbursement_method: 2 categorías únicas
# issue_date_month: 12 categorías únicas
# earliest_cr_line_month: 12 categorías únicas

# %% [markdown]
# We are dropping high-cardinality features to clean noise and reduce bias in the training set.

# %%
df = df.drop(columns=['emp_title'])

# %%
cat_cols = df.select_dtypes(include=['object']).columns
cat_cols
# Out:
# Index(['grade', 'emp_length', 'home_ownership_status', 'verification_status',
#        'loan_purpose', 'addr_state', 'initial_list_status',
#        'disbursement_method', 'issue_date_month', 'earliest_cr_line_month'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2123651 entries, 0 to 2139642
# Data columns (total 42 columns):
#  #   Column                              Dtype
# ---  ------                              -----
#  0   funded_amnt                         int64
#  1   interest_rate                       float64
#  2   monthly_payment                     float64
#  3   grade                               object
#  4   emp_length                          object
#  5   home_ownership_status               object
#  6   annual_income                       float64
#  7   verification_status                 object
#  8   loan_purpose                        object
#  9   addr_state                          object
#  10  dept_paym_income_ratio              float64
#  11  num_30+_delinq_in_2yrs              int64
#  12  num_inq_in_6mths                    int64
#  13  mths_since_last_delinq              float64
#  14  num_open_credit_lines               int64
#  15  num_derogatory_pub_rec              int64
#  16  total_credit_revolving_bal          int64
#  17  used_credit_share                   float64
#  18  tot_num_credit_lines                int64
#  19  initial_list_status                 object
#  20  num_open_trades_in_6mths            float64
#  21  num_installment_acc_op_in_12mths    float64
#  22  num_installment_acc_op_in_24mths    float64
#  23  mths_since_last_installment_acc_op  float64
#  24  num_rev_trades_op_in_12mths         float64
#  25  num_rev_trades_op_in_24mths         float64
#  26  max_bal_owed                        float64
#  27  bal_to_cred_lim                     float64
#  28  num_inq                             float64
#  29  num_inq_in_12mths                   int64
#  30  mths_since_recent_bankcard_delinq   float64
#  31  mths_since_recent_revol_delinq      float64
#  32  disbursement_method                 object
#  33  loan_term_months                    int64
#  34  issue_date_month                    object
#  35  issue_date_year                     int64
#  36  region_code                         int64
#  37  earliest_cr_line_month              object
#  38  earliest_cr_line_year               int64
#  39  PD                                  int64
#  40  LGD                                 float64
#  41  EAD                                 int64
# dtypes: float64(18), int64(14), object(10)
# memory usage: 696.7+ MB

# %%
df['PD']
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 2139638    0
# 2139639    0
# 2139640    0
# 2139641    0
# 2139642    0
# Name: PD, Length: 2123651, dtype: int64

# %%
fig, axes = plt.subplots(nrows=5, ncols=6, figsize=(50, 20))
axes = axes.flatten()

for (i, col) in enumerate(num_cols):
    sns.boxplot(
        data=df, 
        x='PD', 
        y=col, 
        ax=axes[i], 
        palette='viridis',
        orient='v',
        hue='PD',
        legend=False
    )
    axes[i].set_title(f'Distribución de {col}', fontsize=13)
    axes[i].set_xlabel('Cuotas Impagadas (Target)')
    axes[i].set_ylabel(col)
    axes[i].grid(axis='y', linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

# %%
def IQR(df, columnas):
    df_clean = df.copy()
    
    for col in columnas:
        Q1 = df_clean[col].quantile(0.25)
        Q3 = df_clean[col].quantile(0.75)
        IQR = Q3 - Q1
        
        limite_inferior = Q1 - 1.5 * IQR
        limite_superior = Q3 + 1.5 * IQR
        
        outliers_inf = (df_clean[col] < limite_inferior).sum()
        outliers_sup = (df_clean[col] > limite_superior).sum()
        
        df_clean[col] = np.where(df_clean[col] < limite_inferior, Q1, df_clean[col])
        df_clean[col] = np.where(df_clean[col] > limite_superior, Q3, df_clean[col])
        
        print(f"Columna '{col}': {outliers_inf} outliers inferiores -> {Q1:.2f} & {outliers_sup} outliers superiores -> {Q3:.2f}")
        
    return df_clean

df_clean = IQR(df, num_cols)
# Out:
# Columna 'funded_amnt': 0 outliers inferiores -> 8000.00 & 27185 outliers superiores -> 20000.00
# Columna 'interest_rate': 0 outliers inferiores -> 9.49 & 39946 outliers superiores -> 15.88
# Columna 'monthly_payment': 0 outliers inferiores -> 251.58 & 69002 outliers superiores -> 583.89
# Columna 'annual_income': 0 outliers inferiores -> 47210.50 & 99793 outliers superiores -> 95000.00
# Columna 'dept_paym_income_ratio': 0 outliers inferiores -> 11.75 & 1618 outliers superiores -> 24.00
# Columna 'num_30+_delinq_in_2yrs': 0 outliers inferiores -> 0.00 & 399725 outliers superiores -> 0.00
# Columna 'num_inq_in_6mths': 0 outliers inferiores -> 0.00 & 91833 outliers superiores -> 1.00
# Columna 'mths_since_last_delinq': 0 outliers inferiores -> 0.00 & 29603 outliers superiores -> 31.00
# Columna 'num_open_credit_lines': 0 outliers inferiores -> 8.00 & 80309 outliers superiores -> 14.00
# Columna 'num_derogatory_pub_rec': 0 outliers inferiores -> 0.00 & 339840 outliers superiores -> 0.00
# Columna 'total_credit_revolving_bal': 0 outliers inferiores -> 5954.00 & 128614 outliers superiores -> 20090.00
# Columna 'used_credit_share': 0 outliers inferiores -> 31.70 & 118 outliers superiores -> 69.30
# Columna 'tot_num_credit_lines': 0 outliers inferiores -> 15.00 & 37611 outliers superiores -> 31.00
# Columna 'num_open_trades_in_6mths': 0 outliers inferiores -> 0.00 & 118282 outliers superiores -> 1.00
# Columna 'num_installment_acc_op_in_12mths': 0 outliers inferiores -> 0.00 & 57921 outliers superiores -> 1.00
# Columna 'num_installment_acc_op_in_24mths': 0 outliers inferiores -> 0.00 & 264942 outliers superiores -> 1.00
# Columna 'mths_since_last_installment_acc_op': 0 outliers inferiores -> 0.00 & 157635 outliers superiores -> 15.00
# Columna 'num_rev_trades_op_in_12mths': 0 outliers inferiores -> 0.00 & 213069 outliers superiores -> 1.00
# Columna 'num_rev_trades_op_in_24mths': 0 outliers inferiores -> 0.00 & 69410 outliers superiores -> 3.00
# Columna 'max_bal_owed': 0 outliers inferiores -> 0.00 & 112652 outliers superiores -> 5045.00
# Columna 'bal_to_cred_lim': 0 outliers inferiores -> 0.00 & 60 outliers superiores -> 62.00
# Columna 'num_inq': 0 outliers inferiores -> 0.00 & 154632 outliers superiores -> 1.00
# Columna 'num_inq_in_12mths': 0 outliers inferiores -> 0.00 & 100250 outliers superiores -> 2.00
# Columna 'mths_since_recent_bankcard_delinq': 0 outliers inferiores -> 0.00 & 492418 outliers superiores -> 0.00
# Columna 'mths_since_recent_revol_delinq': 0 outliers inferiores -> 0.00 & 250578 outliers superiores -> 17.00
# Columna 'loan_term_months': 0 outliers inferiores -> 36.00 & 0 outliers superiores -> 60.00
# Columna 'issue_date_year': 42504 outliers inferiores -> 2015.00 & 0 outliers superiores -> 2017.00
# Columna 'region_code': 0 outliers inferiores -> 2.00 & 0 outliers superiores -> 8.00
# Columna 'earliest_cr_line_year': 45736 outliers inferiores -> 1995.00 & 0 outliers superiores -> 2005.00

# %%
fig, axes = plt.subplots(nrows=5, ncols=6, figsize=(50, 20))
axes = axes.flatten()

for (i, col) in enumerate(num_cols):
    sns.boxplot(
        data=df_clean, 
        x='PD', 
        y=col, 
        ax=axes[i], 
        palette='viridis',
        orient='v',
        hue='PD',
        legend=False
    )
    axes[i].set_title(f'Distribución de {col}', fontsize=13)
    axes[i].set_xlabel('Cuotas Impagadas (Target)')
    axes[i].set_ylabel(col)
    axes[i].grid(axis='y', linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

# %%
cat_cols
# Out:
# Index(['grade', 'emp_length', 'home_ownership_status', 'verification_status',
#        'loan_purpose', 'addr_state', 'initial_list_status',
#        'disbursement_method', 'issue_date_month', 'earliest_cr_line_month'],
#       dtype='object')

# %% [markdown]
# One-hot encoding:

# %%
df = pd.get_dummies(df, columns=cat_cols, drop_first=True)

# %%
df.columns
# Out:
# Index(['funded_amnt', 'interest_rate', 'monthly_payment', 'annual_income',
#        'dept_paym_income_ratio', 'num_30+_delinq_in_2yrs', 'num_inq_in_6mths',
#        'mths_since_last_delinq', 'num_open_credit_lines',
#        'num_derogatory_pub_rec',
#        ...
#        'earliest_cr_line_month_Dec', 'earliest_cr_line_month_Feb',
#        'earliest_cr_line_month_Jan', 'earliest_cr_line_month_Jul',
#        'earliest_cr_line_month_Jun', 'earliest_cr_line_month_Mar',
#        'earliest_cr_line_month_May', 'earliest_cr_line_month_Nov',
#        'earliest_cr_line_month_Oct', 'earliest_cr_line_month_Sep'],
#       dtype='object', length=168)

# %%
df.head()
# Out:
#    funded_amnt  interest_rate  monthly_payment  annual_income  \
# 0         2500          13.56            84.92        55000.0
# 1        30000          18.94           777.23        90000.0
# 2         5000          17.97           180.69        59280.0
# 3         4000          18.94           146.51        92000.0
# 4        30000          16.14           731.78        57250.0
#
#    dept_paym_income_ratio  num_30+_delinq_in_2yrs  num_inq_in_6mths  \
# 0                   18.24                       0                 1
# 1                   26.52                       0                 0
# 2                   10.51                       0                 0
# 3                   16.74                       0                 0
# 4                   26.35                       0                 0
#
#    mths_since_last_delinq  num_open_credit_lines  num_derogatory_pub_rec  ...  \
# 0                     0.0                      9                       1  ...
# 1                    71.0                     13                       1  ...
# 2                     0.0                      8                       0  ...
# 3                     0.0                     10                       0  ...
# 4                     0.0                     12                       0  ...
#
#    earliest_cr_line_month_Dec  earliest_cr_line_month_Feb  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                        True
# 4                        True                       False
#
#    earliest_cr_line_month_Jan  earliest_cr_line_month_Jul  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    earliest_cr_line_month_Jun  earliest_cr_line_month_Mar  \
# 0                       False                       False
# 1                        True                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    earliest_cr_line_month_May  earliest_cr_line_month_Nov  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    earliest_cr_line_month_Oct  earliest_cr_line_month_Sep
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
# [5 rows x 168 columns]

# %%
df['PD'].value_counts()
# Out:
# PD
# 0    1845023
# 1     278628
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    funded_amnt  interest_rate  monthly_payment  annual_income  \
# 0         2500          13.56            84.92        55000.0
# 1        30000          18.94           777.23        90000.0
# 2         5000          17.97           180.69        59280.0
# 3         4000          18.94           146.51        92000.0
# 4        30000          16.14           731.78        57250.0
#
#    dept_paym_income_ratio  num_30+_delinq_in_2yrs  num_inq_in_6mths  \
# 0                   18.24                       0                 1
# 1                   26.52                       0                 0
# 2                   10.51                       0                 0
# 3                   16.74                       0                 0
# 4                   26.35                       0                 0
#
#    mths_since_last_delinq  num_open_credit_lines  num_derogatory_pub_rec  ...  \
# 0                     0.0                      9                       1  ...
# 1                    71.0                     13                       1  ...
# 2                     0.0                      8                       0  ...
# 3                     0.0                     10                       0  ...
# 4                     0.0                     12                       0  ...
#
#    earliest_cr_line_month_Dec  earliest_cr_line_month_Feb  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                        True
# 4                        True                       False
#
#    earliest_cr_line_month_Jan  earliest_cr_line_month_Jul  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    earliest_cr_line_month_Jun  earliest_cr_line_month_Mar  \
# 0                       False                       False
# 1                        True                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    earliest_cr_line_month_May  earliest_cr_line_month_Nov  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    earliest_cr_line_month_Oct  earliest_cr_line_month_Sep
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
# [5 rows x 168 columns]

# %%
df.shape
# Out:
# (2123651, 168)

# %%
df.to_csv('cleaned_data.csv', index=False)
